# %%
from pickle import load
from utils.model import *
from utils.load_data import loadTrainData, loadValData, data_generator
from utils.getEmbedding import setGlove
from tensorflow.keras.callbacks import ModelCheckpoint
from config import config, rnnConfig
import random
# Setting random seed for reproducibility of results
random.seed(config['random_seed'])

"""
    *Some simple checking
"""
assert type(config['num_of_epochs']) is int, 'Please provide an integer value for `num_of_epochs` parameter in config.py file'
assert type(config['max_length']) is int, 'Please provide an integer value for `max_length` parameter in config.py file'
assert type(config['batch_size']) is int, 'Please provide an integer value for `batch_size` parameter in config.py file'
assert type(config['beam_search_k']) is int, 'Please provide an integer value for `beam_search_k` parameter in config.py file'
assert type(config['random_seed']) is int, 'Please provide an integer value for `random_seed` parameter in config.py file'
assert type(rnnConfig['embedding_size']) is int, 'Please provide an integer value for `embedding_size` parameter in config.py file'
assert type(rnnConfig['LSTM_units']) is int, 'Please provide an integer value for `LSTM_units` parameter in config.py file'
assert type(rnnConfig['dense_units']) is int, 'Please provide an integer value for `dense_units` parameter in config.py file'
assert type(rnnConfig['dropout']) is float, 'Please provide a float value for `dropout` parameter in config.py file'

"""
	*Load Data
	*X1 : Image features
	*X2 : Text features(Captions)
"""
X1train, X2train, max_length = loadTrainData(config)

X1val, X2val = loadValData(config)

"""
	*Load the tokenizer
"""
tokenizer = load(open(config['tokenizer_path'], 'rb'))
vocab_size = len(tokenizer.word_index) + 1

"""
	*Now that we have the image features from CNN model, we need to feed them to a RNN Model.
	*Define the RNN model
"""
model = RNNModel(vocab_size, max_length, rnnConfig, config['model_type'])
#model = AlternativeRNNModel(vocab_size, max_length, rnnConfig, config['model_type'])
#model = InjectRNN(vocab_size, max_length, rnnConfig, config['model_type'])
print('RNN Model (Decoder) Summary : ')
print(model.summary())




### with Pre-trained model(Glove)######
embedding_matrix = setGlove()
model.layers[2].set_weights([embedding_matrix])
model.layers[2].trainable = False

########################################




print('max_len: ', max_length)
"""
    *Train the model save after each epoch
"""
num_of_epochs = config['num_of_epochs']
batch_size = config['batch_size']
steps_train = len(X2train)//batch_size
if len(X2train)%batch_size!=0:
    steps_train = steps_train+1
steps_val = len(X2val)//batch_size
if len(X2val)%batch_size!=0:
    steps_val = steps_val+1
model_save_path = config['model_data_path']+"model_"+str(config['model_type'])+"_epoch-{epoch:02d}_train_loss-{loss:.4f}_val_loss-{val_loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(model_save_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks = [checkpoint]

print('steps_train: {}, steps_val: {}'.format(steps_train,steps_val))
print('Batch Size: {}'.format(batch_size))
print('Total Number of Epochs = {}'.format(num_of_epochs))

# Shuffle train data
ids_train = list(X2train.keys())
random.shuffle(ids_train)
X2train_shuffled = {_id: X2train[_id] for _id in ids_train}
X2train = X2train_shuffled

# Create the train data generator
# returns [[img_features, text_features], out_word]
generator_train = data_generator(X1train, X2train, tokenizer, max_length, batch_size, config['random_seed'])
# Create the validation data generator
# returns [[img_features, text_features], out_word]
generator_val = data_generator(X1val, X2val, tokenizer, max_length, batch_size, config['random_seed'])

# Fit for one epoch
model.fit_generator(generator_train,
            epochs=num_of_epochs,
            steps_per_epoch=steps_train,
            validation_data=generator_val,
            validation_steps=steps_val,
            callbacks=callbacks,
            verbose=1)

"""
	*Evaluate the model on validation data and ouput BLEU score
"""
print('Model trained successfully. Running model on validation set for calculating BLEU score using BEAM search with k={}'.format(config['beam_search_k']))
#evaluate_model_beam_search(model, X1val, X2val, tokenizer, max_length, beam_index=config['beam_search_k'])
evaluate_model(model,X1val,X2val,tokenizer, max_length)
# Out:
# 9:15:7: Using Inceptionv3 model
# 9:15:7: Image features already generated at model_data/features_inceptionv3.pkl
# 9:15:7: Parsed caption file already generated at model_data/captions.txt
# 9:15:7: Available images for training: 6000
# 9:15:7: Available captions for training: 30000
# 9:15:7: Available images for validation: 1000
# 9:15:7: Available captions for validation: 5000
# RNN Model (Decoder) Summary :
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 40)           0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 40, 200)      1475600     input_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           input_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40, 200)      0           embedding_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 200)          409800      dropout_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 256)          467968      dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 456)          0           dense_4[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          116992      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 7378)         1896146     dense_5[0][0]
# ==================================================================================================
# Total params: 4,366,506
# Trainable params: 4,366,506
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# We have 400000 word vectors
# vocab_size: 7378
# max_len:  40
# steps_train: 94, steps_val: 16
# Batch Size: 64
# Total Number of Epochs = 20
# /home/sson/anaconda3/envs/test/lib/python3.6/site-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /home/sson/anaconda3/envs/test/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/20
# /home/sson/anaconda3/envs/test/lib/python3.6/site-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 94/94 [==============================] - 20s 209ms/step - loss: 5.3713 - val_loss: 4.2402
#
# Epoch 00001: val_loss improved from inf to 4.24016, saving model to model_data/model_inceptionv3_epoch-01_train_loss-5.3745_val_loss-4.2402.hdf5
# Epoch 2/20
# 94/94 [==============================] - 19s 207ms/step - loss: 4.0566 - val_loss: 3.5341
#
# Epoch 00002: val_loss improved from 4.24016 to 3.53411, saving model to model_data/model_inceptionv3_epoch-02_train_loss-4.0579_val_loss-3.5341.hdf5
# Epoch 3/20
# 94/94 [==============================] - 20s 209ms/step - loss: 3.5827 - val_loss: 3.2803
#
# Epoch 00003: val_loss improved from 3.53411 to 3.28027, saving model to model_data/model_inceptionv3_epoch-03_train_loss-3.5834_val_loss-3.2803.hdf5
# Epoch 4/20
# 94/94 [==============================] - 18s 194ms/step - loss: 3.3337 - val_loss: 3.1364
#
# Epoch 00004: val_loss improved from 3.28027 to 3.13641, saving model to model_data/model_inceptionv3_epoch-04_train_loss-3.3342_val_loss-3.1364.hdf5
# Epoch 5/20
# 94/94 [==============================] - 19s 198ms/step - loss: 3.1567 - val_loss: 3.0405
#
# Epoch 00005: val_loss improved from 3.13641 to 3.04054, saving model to model_data/model_inceptionv3_epoch-05_train_loss-3.1572_val_loss-3.0405.hdf5
# Epoch 6/20
# 94/94 [==============================] - 18s 195ms/step - loss: 3.0215 - val_loss: 2.9743
#
# Epoch 00006: val_loss improved from 3.04054 to 2.97434, saving model to model_data/model_inceptionv3_epoch-06_train_loss-3.0219_val_loss-2.9743.hdf5
# Epoch 7/20
# 94/94 [==============================] - 20s 211ms/step - loss: 2.9128 - val_loss: 2.9425
#
# Epoch 00007: val_loss improved from 2.97434 to 2.94246, saving model to model_data/model_inceptionv3_epoch-07_train_loss-2.9133_val_loss-2.9425.hdf5
# Epoch 8/20
# 94/94 [==============================] - 18s 195ms/step - loss: 2.8211 - val_loss: 2.9386
#
# Epoch 00008: val_loss improved from 2.94246 to 2.93857, saving model to model_data/model_inceptionv3_epoch-08_train_loss-2.8215_val_loss-2.9386.hdf5
# Epoch 9/20
# 94/94 [==============================] - 20s 211ms/step - loss: 2.7435 - val_loss: 2.9494
#
# Epoch 00009: val_loss did not improve from 2.93857
# Epoch 10/20
# 94/94 [==============================] - 18s 191ms/step - loss: 2.6744 - val_loss: 2.9364
#
# Epoch 00010: val_loss improved from 2.93857 to 2.93639, saving model to model_data/model_inceptionv3_epoch-10_train_loss-2.6749_val_loss-2.9364.hdf5
# Epoch 11/20
# 94/94 [==============================] - 19s 199ms/step - loss: 2.6133 - val_loss: 2.9335
#
# Epoch 00011: val_loss improved from 2.93639 to 2.93347, saving model to model_data/model_inceptionv3_epoch-11_train_loss-2.6137_val_loss-2.9335.hdf5
# Epoch 12/20
# 94/94 [==============================] - 19s 202ms/step - loss: 2.5572 - val_loss: 2.9287
#
# Epoch 00012: val_loss improved from 2.93347 to 2.92875, saving model to model_data/model_inceptionv3_epoch-12_train_loss-2.5576_val_loss-2.9287.hdf5
# Epoch 13/20
# 94/94 [==============================] - 18s 189ms/step - loss: 2.5046 - val_loss: 2.9221
#
# Epoch 00013: val_loss improved from 2.92875 to 2.92214, saving model to model_data/model_inceptionv3_epoch-13_train_loss-2.5050_val_loss-2.9221.hdf5
# Epoch 14/20
# 94/94 [==============================] - 19s 199ms/step - loss: 2.4575 - val_loss: 2.8982
#
# Epoch 00014: val_loss improved from 2.92214 to 2.89819, saving model to model_data/model_inceptionv3_epoch-14_train_loss-2.4579_val_loss-2.8982.hdf5
# Epoch 15/20
# 94/94 [==============================] - 19s 197ms/step - loss: 2.4144 - val_loss: 2.8928
#
# Epoch 00015: val_loss improved from 2.89819 to 2.89284, saving model to model_data/model_inceptionv3_epoch-15_train_loss-2.4148_val_loss-2.8928.hdf5
# Epoch 16/20
# 94/94 [==============================] - 18s 193ms/step - loss: 2.3713 - val_loss: 2.8732
#
# Epoch 00016: val_loss improved from 2.89284 to 2.87320, saving model to model_data/model_inceptionv3_epoch-16_train_loss-2.3717_val_loss-2.8732.hdf5
# Epoch 17/20
# 94/94 [==============================] - 18s 195ms/step - loss: 2.3340 - val_loss: 2.8678
#
# Epoch 00017: val_loss improved from 2.87320 to 2.86779, saving model to model_data/model_inceptionv3_epoch-17_train_loss-2.3344_val_loss-2.8678.hdf5
# Epoch 18/20
# 94/94 [==============================] - 18s 195ms/step - loss: 2.3027 - val_loss: 2.8864
#
# Epoch 00018: val_loss did not improve from 2.86779
# Epoch 19/20
# 94/94 [==============================] - 18s 192ms/step - loss: 2.2700 - val_loss: 2.8960
#
# Epoch 00019: val_loss did not improve from 2.86779
# Epoch 20/20
# 94/94 [==============================] - 19s 203ms/step - loss: 2.2401 - val_loss: 2.8972
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 00020: val_loss did not improve from 2.86779
# Model trained successfully. Running model on validation set for calculating BLEU score using BEAM search with k=3
# 100%|██████████| 1000/1000 [02:40<00:00,  6.23it/s]
# BLEU Scores :
# A perfect match results in a score of 1.0, whereas a perfect mismatch results in a score of 0.0.
# BLEU-1: 0.590970
# BLEU-2: 0.339697
# BLEU-3: 0.234045
# BLEU-4: 0.115726
